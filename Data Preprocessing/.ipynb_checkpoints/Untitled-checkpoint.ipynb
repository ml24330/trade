# %%
import pandas as pd
import numpy as np

data = pd.read_csv('fta.csv')
data['Date signed'] = pd.to_datetime(data['Date signed'])
data['Date into force'] = pd.to_datetime(data['Date into force'])
data['Date of notification'] = pd.to_datetime(data['Date of notification'])
data['End of implementation'] = pd.to_datetime(data['End of implementation'])
data['Date inactive'] = pd.to_datetime(data['Date inactive'])
data['Region'] = data['Region'].astype('string')

# data[data['Composition'] == 'Bilateral'].shape
data['Region'].value_counts
# Out:
# <bound method DataFrame.value_counts of                                                 Name  \
# 0     South Africa - Southern Rhodesia Customs Union
# 1            El Salvador - Nicaragua Free Trade Area
# 2                                          EC Treaty
# 3                   Central American Free Trade Area
# 4    Equatorial Customs Union - Cameroon Association
# ..                                               ...
# 445                        Trans-Pacific Partnership
# 446                        Trans-Pacific Partnership
# 447                               EFTA - Philippines
# 448                                 Canada - Ukraine
# 449                                       EU - Ghana
#
#                                                   Type  WTO ID  Identifier  \
# 0                                        Customs Union   360.0         310
# 1                                 Free Trade Agreement   297.0         254
# ...
